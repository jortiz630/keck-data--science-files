# %%
import numpy as np
from PyAstronomy import pyasl
from astropy.io import fits
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
SampleFile = "HI.20060307.18529.fits.gz"
hdul = fits.open(SampleFile)
hdul.info()
# Out:
# Filename: HI.20060307.18529.fits.gz
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU     813   ()
#   1  VidInp2       1 ImageHDU       360   (1070, 4096)   int16 (rescales to uint16)
#   2  VidInp4       1 ImageHDU       360   (1070, 4096)   int16 (rescales to uint16)
#   3  VidInp6       1 ImageHDU       360   (1070, 4096)   int16 (rescales to uint16)

# %%
data1 = hdul[1].data
data2 = hdul[2].data
data3 = hdul[3].data

data1Array = np.array(data1)
data2Array = np.array(data2)
data3Array = np.array(data3)

plt.figure(figsize=(20,10))
plt.imshow(data1Array)
plt.show()

# %%
plt.figure(figsize=(20,10))
plt.imshow(data2Array)
plt.show()

# %%
plt.figure(figsize=(20,10))
plt.imshow(data3Array)
plt.show()

# %%
data1 = hdul[0].data

data1Array = np.array(data1)

plt.figure(figsize=(20,10))
plt.plot(data1Array)
plt.show()
